# %%
import pandas as pd
rw = pd.read_csv('dataset/jfk_weather.csv')
rw.shape
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8,10,11,12,13,14,15,16,17,20,22,23,25,40,63,64,67,68,69,84,85,86,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (114545, 90)

# %%
cw = pd.read_csv('dataset/jfk_weather_cleaned.csv')
cw.shape
# Out:
# (75119, 16)

# %%
cw.keys()
# Out:
# Index(['DATE', 'HOURLYVISIBILITY', 'HOURLYWindSpeed', 'HOURLYPrecip',
#        'HOURLYRelativeHumidity', 'HOURLYDRYBULBTEMPF', 'HOURLYWETBULBTEMPF',
#        'HOURLYDewPointTempF', 'HOURLYStationPressure',
#        'HOURLYSeaLevelPressure', 'HOURLYAltimeterSetting',
#        'HOURLYWindDirectionSin', 'HOURLYWindDirectionCos',
#        'HOURLYPressureTendencyIncr', 'HOURLYPressureTendencyDecr',
#        'HOURLYPressureTendencyCons'],
#       dtype='object')

# %%
# HOURLY VISIBILITY than 0.5
cw['HOURLYVISIBILITY'][cw['HOURLYVISIBILITY'] <0.5]
# Out:
# 591      0.120000
# 973      0.250000
# 974      0.250000
# 975      0.250000
# 979      0.250000
#            ...
# 73751    0.120000
# 73752    0.245714
# 73753    0.371429
# 73754    0.497143
# 73770    0.120000
# Name: HOURLYVISIBILITY, Length: 1102, dtype: float64

# %%
# HOURLY Wind Speed over than 35
cw['HOURLYWindSpeed'][cw['HOURLYWindSpeed'] > 35]
# Out:
# 588      39.0
# 1719     46.0
# 1720     44.0
# 1721     44.0
# 1722     40.0
#          ...
# 71585    39.0
# 71592    37.0
# 71593    36.0
# 71594    36.0
# 72650    36.0
# Name: HOURLYWindSpeed, Length: 74, dtype: float64

# %%
# HOURLY Precip over than 1
cw['HOURLYPrecip'][cw['HOURLYPrecip'] >0.99]
# Out:
# 5613     1.15
# 6557     1.10
# 14163    2.41
# 14347    1.26
# 21751    1.52
# 22859    1.76
# 40442    1.54
# 49396    1.67
# 57544    1.45
# 65866    1.37
# 75115    1.16
# Name: HOURLYPrecip, dtype: float64

# %%
import matplotlib.pyplot as plt
 
num_list = Counter(training_data['month'][training_data['arr_delay'] < 0])
plt.bar(range(len(num_list)), num_list)
plt.xlim(1, 12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a7bd899c3a4a> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 num_list = Counter(training_data['month'][training_data['arr_delay'] < 0])
#       4 plt.bar(range(len(num_list)), num_list)
#       5 plt.xlim(1, 12)
#
# NameError: name 'Counter' is not defined

# %%
cw.hist(bins=50,figsize=(60,45)) #bins总个数，figsize图的大小
# Out:
# array([[<AxesSubplot:title={'center':'HOURLYVISIBILITY'}>,
#         <AxesSubplot:title={'center':'HOURLYWindSpeed'}>,
#         <AxesSubplot:title={'center':'HOURLYPrecip'}>,
#         <AxesSubplot:title={'center':'HOURLYRelativeHumidity'}>],
#        [<AxesSubplot:title={'center':'HOURLYDRYBULBTEMPF'}>,
#         <AxesSubplot:title={'center':'HOURLYWETBULBTEMPF'}>,
#         <AxesSubplot:title={'center':'HOURLYDewPointTempF'}>,
#         <AxesSubplot:title={'center':'HOURLYStationPressure'}>],
#        [<AxesSubplot:title={'center':'HOURLYSeaLevelPressure'}>,
#         <AxesSubplot:title={'center':'HOURLYAltimeterSetting'}>,
#         <AxesSubplot:title={'center':'HOURLYWindDirectionSin'}>,
#         <AxesSubplot:title={'center':'HOURLYWindDirectionCos'}>],
#        [<AxesSubplot:title={'center':'HOURLYPressureTendencyIncr'}>,
#         <AxesSubplot:title={'center':'HOURLYPressureTendencyDecr'}>,
#         <AxesSubplot:title={'center':'HOURLYPressureTendencyCons'}>,
# ...
